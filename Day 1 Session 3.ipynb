# %%
import pandas as pd

# %%
import os

os.chdir('C:/Users/gaura/Downloads/Data')

# %%
ls
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 02D7-169A
#
#  Directory of C:\Users\gaura\Downloads\Data
#
# 31-01-2020  15:32    <DIR>          .
# 31-01-2020  15:32    <DIR>          ..
# 31-01-2020  10:40           151,004 Analysis - 3.xlsx
# 22-01-2020  19:54            16,366 Data f or sql.xlsx
# 22-01-2020  20:35             7,205 Infoica.csv
# 22-01-2020  20:36             8,704 Name.xlsx
# 31-01-2020  15:30            59,388 Session 3.xlsx
# 31-01-2020  10:40            19,400 student.xlsx
#                6 File(s)        262,067 bytes
#                2 Dir(s)  151,369,027,584 bytes free

# %%
df = pd.read_excel("Session 3 raw data.xlsx", sheet_name="Sheet1")

# %%
df.head(1)
# Out:
#    Ecode                Name Status        DOJ  Total Time Taken (Second)  \
# 0  32416  Tanya Adah Agarwal    CON 2012-11-23                     862145
#
#   Formatted Time  AHT  Total Tenure  Tenure (in days)  Salary  Attendance  \
# 0          delhi  NaN           NaN               NaN   34065          29
#
#    Total Tasks Assigned  Task Completed  Flagged  Task Complted%
# 0                  1401            1345       70       96.002855

# %%
df.columns
# Out:
# Index(['Ecode', 'Name', 'Status', 'DOJ', 'Total Time Taken (Second)',
#        'Formatted Time', 'AHT', 'Total Tenure', 'Tenure (in days)', 'Salary',
#        'Attendance', 'Total Tasks Assigned', 'Task Completed', 'Flagged',
#        'Task Complted%'],
#       dtype='object')

# %%
df["Attendence%"] = (df['Attendance']/31)*100

# %%
df.columns
# Out:
# Index(['Ecode', 'Name', 'Status', 'DOJ', 'Total Time Taken (Second)',
#        'Formatted Time', 'AHT', 'Total Tenure', 'Tenure (in days)', 'Salary',
#        'Attendance', 'Total Tasks Assigned', 'Task Completed', 'Flagged',
#        'Task Complted%', 'Attendence%'],
#       dtype='object')

# %%
df.round({"Attendence%":2})
# Out:
#     Ecode                      Name Status        DOJ  \
# 0   32416        Tanya Adah Agarwal    CON 2012-11-23
# 1   32417        Tanvi Adhira Agate    PRO 2015-02-25
# 2   32418     Rohit Alisha Aggarwal    PRO 2017-07-04
# 3   32419        Vani Amoli Agrawal    PRO 2007-09-05
# 4   32420    Yash Anaisha Ahluwalia    PRO 2019-03-05
# ..    ...                       ...    ...        ...
# 94  32510  Siddharth Vihaan Chander    CON 2008-05-19
# 95  32511     Vedant Vivaan Chandra    CON 2012-08-18
# 96  32512    Shashank Yash Chandran    CON 2019-08-13
# 97  32513            Tisha Yug Char    CON 2014-01-01
# 98  32514      Ram Zuber Chatterjee    PRO 2006-01-25
#
#     Total Time Taken (Second) Formatted Time  AHT  Total Tenure  \
# 0                      862145          delhi  NaN           NaN
# 1                      647757            NaN  NaN           NaN
# 2                     3482328            NaN  NaN           NaN
# ...

# %%
df.head(3)
# Out:
#    Ecode                   Name Status        DOJ  Total Time Taken (Second)  \
# 0  32416     Tanya Adah Agarwal    CON 2012-11-23                     862145
# 1  32417     Tanvi Adhira Agate    PRO 2015-02-25                     647757
# 2  32418  Rohit Alisha Aggarwal    PRO 2017-07-04                    3482328
#
#   Formatted Time  AHT  Total Tenure  Tenure (in days)  Salary  Attendance  \
# 0          delhi  NaN           NaN               NaN   34065          29
# 1            NaN  NaN           NaN               NaN   50567          31
# 2            NaN  NaN           NaN               NaN   54485          31
#
#    Total Tasks Assigned  Task Completed  Flagged  Task Complted%  Attendence%
# 0                  1401            1345       70       96.002855    93.548387
# 1                   900             891      513       99.000000   100.000000
# 2                  1789            1556      429       86.975964   100.000000

# %%
df['Attendence%'].round(2)
# Out:
# 0      93.55
# 1     100.00
# 2     100.00
# 3      83.87
# 4      80.65
#        ...
# 94      0.00
# 95      0.00
# 96      0.00
# 97     80.65
# 98     87.10
# Name: Attendence%, Length: 99, dtype: float64
